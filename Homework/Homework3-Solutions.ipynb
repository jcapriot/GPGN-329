# %% [markdown]
# # Homework 3 - Waves in elastic medium
# Due May 3rd, 2024

# %% [markdown]
# ## Apparent velocity
# Consider a harmonic planewave p-wave propogating along the x-z plane:
#
# $$
# \phi(x, z, t) = A e^{i(\omega t - k_x x + k_z z)} \hspace{20pt} (1)
# $$
#
# where are usual, $\omega$ is the angular frequency and $k_x$ and $k_z$ are the wavenumbers (which all must be positive values).

# %% [markdown]
# 1) Which direction is the wave traveling (what is $\vec{k}$)?

# %% [markdown]
# ### Solution
# The wave is traveling in the:
# \begin{align}
# \vec{k} = k_x \hat{x} - k_z \hat{z}
# \end{align}
# which is in the positive x direction and negative z direction.

# %% [markdown]
# 2. What is the speed of this wave in terms of $\omega$, $k_x$, and $k_z$? (Recall the relationship between $\omega$ and $|\vec{k}|$)

# %% [markdown]
# ### Solution
#
# \begin{align}
# v &= \frac{\omega}{|\vec{k}|}\\
# v &= \frac{\omega}{\sqrt{k_x^2 + k_z^2}}
# \end{align}

# %% [markdown]
# 3. What is the $x$ component of the $\hat{k}$ (the unit vector in the direction of $\vec{k})$?

# %% [markdown]
# ### Solution
#
# \begin{align}
# \hat{k} &= \frac{\vec{k}}{|\vec{k}|}\\
# \hat{k}_x &= \frac{k_x}{\sqrt{k_x^2 + k_y^2}}
# \end{align}

# %% [markdown]
# 5. What is the x-component of the wave's velocity, (the vector $\vec{v} = v \hat{k}$, so what is its x-component.)

# %% [markdown]
# ### Solution
#
# \begin{align}
# \vec{v} &= v \hat{k}\\
# v_x &= v\hat{k}_x\\
# &= \frac{\omega}{\sqrt{k_x^2 + k_z^2}} \hat{k}_x\\
# &= \frac{\omega}{\sqrt{k_x^2 + k_z^2}} \frac{k_x}{\sqrt{k_x^2 + k_z^2}}\\
# v_x &= \frac{\omega k_x}{k_x^2 + k_z^2}
# \end{align}

# %% [markdown]
# 6. What is the equation for the wave as it intersects a plane at $z=0$? (what is (1) with $z=0$)?

# %% [markdown]
# ### Solution
# \begin{align}
# \phi(x, z=0, t) = A e^{i(\omega t - k_x x + k_z 0)}\\
# \phi(x, z=0, t) = A e^{i(\omega t - k_x x)}
# \end{align}

# %% [markdown]
# 7. Which direction is the wave "apparently" traveling along the plane at $z=0$?

# %% [markdown]
# ### Solution
# In the $+\hat{x}$ direction.

# %% [markdown]
# 8. What is the "apparent velocity" of the wave along the plane at $z=0$? (What is the speed of the wave from your equation in part 6?)

# %% [markdown]
# ### Solution
# \begin{align}
# v_{apparent} = \frac{\omega}{k_x}
# \end{align}

# %% [markdown]
# 8. How does the apparent velocity of the wave along the plane at $z=0$ compare to the true $x$ component of the wave's velocity (is it smaller or larger?)

# %% [markdown]
# ### Solution
#
# \begin{align}
# v_{apparent} &= \frac{\omega}{k_x}\\
# v_x &= \frac{\omega k_x}{k_x^2 + k_z^2}\\
# v_x &= \frac{\omega}{k_x + k_z^2/k_x}\\
# v_{apparent} &? v_x\\
# \frac{\omega}{k_x} &? \frac{\omega}{k_x + k_z^2/k_x}\\
# \frac{1}{k_x} &? \frac{1}{k_x + k_z^2/k_x}\\
# k_x &\leq k_x + k_z^2/k_x\\
# \frac{1}{k_x} &\geq \frac{1}{k_x + k_z^2/k_x}\\
# v_{apparent} &\geq v_x
# \end{align}
#
# The apparent velocity along the z=0 plane will be greater than or equal to the x-component of the wave's velocity.

# %% [markdown]
# 9. Under what condition will the two be equal to each other? (Hint: there's a specific value of $k_z$ such that $v_{apparent} = v_x$)

# %% [markdown]
# ### Solution
#
# \begin{align}
# v_{apparent} &= v_x&\\
# \frac{\omega}{k_x} &= \frac{\omega}{k_x + k_z^2/k_x} &\iff k_z=0
# \end{align}
#
# The apparent velocity and the true velocity of the wave will be equal to each other if and only if $k_z=0$. Meaning to say the wave is traveling only in the $+\hat{x}$ direction.

# %% [markdown]
# 10. What is the apparent velocity of the wave for $k_z>>k_x$ (The limit of $v_{apparent}$ as $k_x \rightarrow 0$)?

# %% [markdown]
# ### Solution
# \begin{align}
# \lim_{k_x\rightarrow0} v_{apparent} &= \lim_{k_x\rightarrow0} \frac{\omega}{k_x}\\
# &= \infty
# \end{align}

# %% [markdown]
# ## Numerical PDE
# Consider the following 1D partial differential equation for $u_y$, describing the motion of waves along a string with non-constant velocity ($v$) (but a constant density):
#
# $$
# \frac{\partial}{\partial x} v(x)^2 \frac{\partial u_y}{\partial x} + h(x,t)= \frac{\partial^2 u_y}{\partial t^2}
# $$
# subject to initial conditions on $u_y(x, t=0)$ and boundary conditions on $u_y(x=0, t)$ and $u_y(x=L, t)$, which will be given. $h$ is a source function.
#
# This is a general form of our equation of motion for elastic medium (but only in 1D). It describes wave motion through an inhomogenous medium.
#
# There are three primary approximations to derivatives that make up the basis of numerical solutions to PDE's:
#
# They are:
#
# *The forward difference approximation to the first derivative of a function,
# $$f'(x) \approx \frac{f(x+\Delta x) - f(x)}{\Delta x}$$
# * The backwards difference approximation to the first derivative of a function,
# $$f'(x) \approx \frac{f(x) - f(x-\Delta x)}{\Delta x}$$
# * The centered second difference approximation to the second derivative of a function,
# $$f''(x) \approx \frac{f(x-\Delta x) - 2 f(x) + f(x + \Delta x)}{\Delta x^2}$$

# %% [markdown]
# ### a)
# Use a first order taylor expansion on $f(x+\Delta x)$ to verify the forward difference approximation to $f'(x)$.

# %% [markdown]
# ### Solution
# \begin{align}
# f(x + \Delta x) &= f(x) + \frac{1}{\Delta x} f'(x) + ... \\
# f'(x) &\approx \frac{f(x+\Delta x) - f(x)}{\Delta x}
# \end{align}

# %% [markdown]
# ### b)
# Let's define our forward difference operator that approximates the derivative of function $f$ at grid point $i$, in terms of the value of $f$ at the grid points ($f_i$):
# $$\delta_+ f = \frac{f_{i+1} - f_i}{\Delta}
# $$
#
# Similarly the backwards difference operator is:
#
# $$\delta_- f = \frac{f_{i} - f_{i-1}}{\Delta}
# $$
#
# and the centered second derivative operator is:
# $$
# \delta^2 f = \frac{f_{i-1}  - 2 f_i + f_{i+1}}{\Delta^2}
# $$
#
# **Show** that $\delta^2 f = \delta_- (\delta_+ f)$
#
# (Hint: Start by defining $(\delta_+ f)_i = g_i$ and applying the backward difference to $g$, $\delta_- g$)
#
# \begin{align}
# g_i = (\delta_+ f)_i &= \frac{f_{i+1} - f_i}{\Delta}\\
# (\delta_- g)_i &= \frac{g_{i} - g_{i-1}}{\Delta}\\
# \end{align}

# %% [markdown]
# ### Solution
#
# \begin{align}
# g_i = (\delta_+ f)_i &= \frac{f_{i+1} - f_i}{\Delta}\\
# (\delta_- g)_i &= \frac{g_{i} - g_{i-1}}{\Delta}\\
# (\delta_- g)_i &= \frac{1}{\Delta}\bigg(\frac{f_{i+1} - f_{i}}{\Delta} - \frac{f_{i} - f_{i-1}}{\Delta}\bigg)\\
# &= \frac{1}{\Delta}\bigg(\frac{f_{i+1} - f_{i} - (f_i - f_{i-1})}{\Delta}\bigg)\\
# &= \frac{1}{\Delta}\bigg(\frac{f_{i+1} - 2f_{i} + f_{i-1}}{\Delta}\bigg)\\
# &= \frac{f_{i+1} - 2f_{i} + f_{i-1}}{\Delta^2}\\
# &= \delta^2 f
# \end{align}

# %% [markdown]
# ## Numerical implementation:
# For the next few parts of this question here's a few bits of information:
#
# Let us define a few quantities:
#
#    * a grid of time coordinates for $t$ such that:
#        $$ t_j = t_0 + j \Delta t $$
#    * a grid of spatial coordinates for $x$ such that:
#        $$ x_k = x_0 + k \Delta x $$
#    * The value of $u$ at $t_j$ and $x_k$
#      $$u_k^j = u(t_j, x_k)$$
#    * The value of $v$ at $x_k$ as:
#      $$v_k = v(x_k)$$
#
# If we use the approximations to the derivatives to write our numerical approximation to the PDE we will write this as:
#
# $$
# \delta_- (v^2 \delta_+ u) = \delta^2 u
# $$
#
# which when expanded completly out yields our discretized PDE:
#
# $$
#  \frac{1}{\Delta x}\bigg(v^2_k \frac{u_{k+1}^j - u_{k}^j}{\Delta x} - v^2_{k-1} \frac{u_{k}^j - u_{k-1}^j}{\Delta x}\bigg) = \rho \frac{u_k^{j-1} - 2 u_k^j + u_k^{j+1}}{\Delta t^2}
# $$
#
# We solve this by stepping through time in a forward Euler method, rearrange the above equation to isolate $u^{j+1}_k$:
#
# \begin{align}
# u^{j+1}_k &= \frac{\Delta t^2}{\Delta x^2}\bigg(v^2_k (u_{k+1}^j - u_{k}^j) - v^2_{k-1} (u_{k}^j - u_{k-1}^j)\bigg) - u^{j-1}_k + 2 u^{j}_k
# \end{align}

# %% [markdown]
# Essentially we provide some initial conditions on $u_k^{0}$ and $u_k^{1}$ and some boundary values for $u_{0}^j$ and $u_{N}^j$, and loop!
#
# #### Implementation:
#
# I have provided you with a simple simulation script, that uses a 0 nuemann boundary at $x_0$ and a 0 dirichlet boundary at $x_N$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def wave_simulator(
    x_grid, t_grid, velocity, pulse_length=0.025, pulse_time=0.05, pulse_location=20, auto_scale=True
):
    n_t = len(t_grid)
    n_x = len(x_grid)
        
    dt = t_grid[1] - t_grid[0]
    dx = x_grid[1] - x_grid[0]
    u = np.empty((n_t, n_x))
    u[:, -1] = 0 # the boundary at the end of the rope is a 0 dirichlet
    u[:, 0] = 0

    a = dt**2/dx**2

    # use u(t=0)=0, u't(t=0)=0
    # basically it means that nothing is happening until we force it.
    ujm2 = np.zeros(n_x)
    ujm1 = ujm2
    
    def f(t, x):
        x = np.asarray(x)
        f = np.zeros(len(x), dtype=float)
        pulse_ind = np.argmin(np.abs(x - pulse_location))
    
        arg = (t-pulse_time)* 2 * np.pi /pulse_length
        if arg > -np.pi and arg < np.pi:
            f[pulse_ind] = -np.sin(arg/2)
        return f

    for j in range(n_t):
        ujm1[0] = ujm1[1]
        gj = velocity[:-1]**2*(ujm1[1:] - ujm1[:-1])

        u[j, 1:-1] = (
            a * (gj[1:]- gj[:-1])
            + dt**2 * f(t_grid[j], x_grid[1:-1])
            + 2 * ujm1[1:-1] - ujm2[1:-1]
        )

        ujm2 = ujm1
        ujm1 = u[j]
    if auto_scale:
        u /= max(np.abs(u.min()), np.abs(u.max()))
    return u

# %% [markdown]
# #### Solving it
# Here I have set up a grid with $\Delta_x=0.5$m from 0 to 200m, $\Delta t=0.001$s, from 0 to 2 seconds, and a constant velocity of $v_1=500 m/s$.
#
# The forcing function is also defined in terms of a time, length, and location. The force is applied at $x=20$m.

# %%
# define the grid points
xs = np.linspace(0, 200, 401)
ts = np.linspace(0, 2, 2001)

v1 = np.ones_like(xs)*500 # m/s

# %% [markdown]
# ### c)
# What is the value of $\frac{\Delta t}{\Delta x} v$?

# %%
0.001/0.5 * 500
# Out:
# 1.0

# %% [markdown]
# ### d)
# Run the "wave simulator" with these simple parameters, and answer some questions.
#
# * What happens to the amplitude of the wave on the left hand side (Which has a free boundary)?
#
# * What happens to the amplitude of the wave on the right hand side (Which has a fixed boundary)?

# %%
u1 = wave_simulator(xs, ts, v1)

plt.pcolormesh(xs, ts, u1, cmap='seismic', clim=[-1, 1])
plt.title('Wavefield')
plt.xlabel('position (m)')
plt.ylabel('time (s)');

# %% [markdown]
# ### Solution
# * At the left boundary the wave is reflected with the same amplitude.
# * At the right boundary the wave is reflected with the opposite sign amplitude.

# %% [markdown]
# ### e)
# This time run the wave simulator with a higher velocity $v_2=1000m/s$, and tell me:
#
# * Does it work?
# * What is $\frac{\Delta t}{\Delta x} v$ in this case

# %%
v2 = np.ones_like(xs)*1000 # m/s

u2 = wave_simulator(xs, ts, v2)

plt.pcolormesh(xs, ts, u2, cmap='seismic', clim=[-1, 1])
plt.title('Wavefield')
plt.xlabel('position (m)')
plt.ylabel('time (s)');
# Out:
# /var/folders/84/p2kwn61561lg6qxvs6gwhy780000gp/T/ipykernel_29614/2809277357.py:32: RuntimeWarning: overflow encountered in multiply
#   gj = velocity[:-1]**2*(ujm1[1:] - ujm1[:-1])
# /var/folders/84/p2kwn61561lg6qxvs6gwhy780000gp/T/ipykernel_29614/2809277357.py:35: RuntimeWarning: overflow encountered in subtract
#   a * (gj[1:]- gj[:-1])
# /var/folders/84/p2kwn61561lg6qxvs6gwhy780000gp/T/ipykernel_29614/2809277357.py:35: RuntimeWarning: invalid value encountered in add
#   a * (gj[1:]- gj[:-1])
# /var/folders/84/p2kwn61561lg6qxvs6gwhy780000gp/T/ipykernel_29614/2809277357.py:32: RuntimeWarning: invalid value encountered in subtract
#   gj = velocity[:-1]**2*(ujm1[1:] - ujm1[:-1])

# %% [markdown]
# ### Solution:
# * No it didn't work

# %%
0.001/0.5 * 1000
# Out:
# 2.0

# %% [markdown]
# ### f)
# This time run the wave simulator with a lower velocity $v_3=250m/s$, and tell me:
#
# * Does it work?
# * What is $\frac{\Delta t}{\Delta x} v$ in this case

# %%
v3 = np.ones_like(xs)*250 # m/s

u3 = wave_simulator(xs, ts, v3)

plt.pcolormesh(xs, ts, u3, cmap='seismic', clim=[-1, 1])
plt.title('Wavefield')
plt.xlabel('position (m)')
plt.ylabel('time (s)');

# %% [markdown]
# ### Solution
# * It does work now! (but there is a little bit of numerical dispersion)

# %%
0.001/0.5 * 250
# Out:
# 0.5

# %% [markdown]
# You might have noticed that it failed when:
# $$\frac{\Delta t}{\Delta x} v > 1$$
#
# This is called a stability condition for the numerical PDE! Your simulations will break if you violate this stability condition.

# %% [markdown]
# ### g)
# Now come up with your own velocity model (just remember that your maximum velocity should still not violate the stability condition).
#
# Depending on your conditions, you may notice some numerical dispersion (but it should still at least be solvable if you account for stability).
#
# For example:

# %%
v4 = np.ones_like(xs)*500 # m/s
v4[xs>100] = 250 # m/s
v4[xs<50] = 100

u4 = wave_simulator(xs, ts, v4)

plt.pcolormesh(xs, ts, u4, cmap='seismic', clim=[-1, 1])
plt.title('Wavefield')
plt.xlabel('position (m)')
plt.ylabel('time (s)');

# %% [markdown]
# ### Solution!
# * Really anything you want to show above (It should at least look interesting.
# * Some things you will likely observe about this though:
#   * The slope of these lines is the $1/v$ (Slowness)
#   * When the wave intersects a boundary going from a slow material to a fast material, the reflected wave has the opposite sign.
#   * When the wave intersects a boundary going from a fast material to a slow material, the reflected wave has the same sign.
