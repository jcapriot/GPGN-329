# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.constants import mu_0

# %% [markdown]
# # GPGN 329 - Physics of the Earth II, Midterm
# * Instructor: Joseph Capriotti jcapriot@mines.edu
# * Due: 5:00PM March 29, 2024
#
# ## Instructions
# * You have between class time on Thursday March 28, and the due date to complete this test.
# * There are XX number of questions **Answer all of them.**
# * **Read the questions carefully.**
# * You **MAY** use your notes, internet, textbooks, etc.
# * You **MAY NOT** discuss the questions with anyone besides the TA or Instructor until after the test is complete. Your submitted work must be your own.
# * Read and sign “Colorado School of Mines Academic Integrity", please. The exam will not be graded without your signature.
# * **GLHF**

# %% [markdown]
# ---
# ## Colorado School of Mines Academic Integrity pledge
#
# _**PREAMBLE**_: Mines students believe it is our responsibility to promote and maintain high ethical standards in order to ensure our safety, welfare, and enjoyment of a successful learning environment. Each of us, under this Code, shall assume responsibility for our behavior in the area of academic integrity.
#
# _**CODE**_: As a Mines student, I am expected to adhere to the highest standards of academic excellence and personal integrity regarding my schoolwork, exams, academic projects, and research
# endeavors. I will act honestly, responsibly, and above all with honor and integrity in all aspects of my academic endeavors at Mines. I will not misrepresent the work of others as my own, nor will I give or receive unauthorized assistance in the performance of academic coursework. I will conduct myself in an ethical manner in my use of the library, computing center, and all other school facilities and resources. By practicing these principles, I will strive to uphold the principles of integrity and academic excellence at Mines. I will not participate in or tolerate any form of discrimination or mistreatment of anther individual.
#
# In regards to this exam, by signing, I guarantee that
# * I will NOT discuss, share information, or work on any exam problem with any other person in any
# format (these "discussions" refer to communication of ANY type).
#
# **Signed Name**_______________________________________________ **Date**_____________________
#
# **Printed Name**_______________________________________________
#
# ---

# %% [markdown]
# ### 1. (X points)
# For this question, please annotate the following image
#
# 1) Plot and label (i.e. annotate them with their name) the following numbers on the complex plane in Figure 1:
# * $z_1 = 2 + 3i$
# * $z_2 = -2 + 3i$
# * $z_3 = 2 e^{-i\pi/4}$
# * $z_4 = z_2 * e^{i\pi/2} $

# %%
z1 = 2 + 3j
z2 = -2 + 3j
z3 = 2 * np.exp(-1j * np.pi/4)
z4 = z2 * np.exp(1j * np.pi/2)

fig = plt.figure(dpi=200)
ax = fig.add_subplot(1, 1, 1)

ax.scatter(z1.real, z1.imag, label='$z_1$')
ax.scatter(z2.real, z2.imag, label='$z_2$')
ax.scatter(z3.real, z3.imag, label='$z_3$')
ax.scatter(z4.real, z4.imag, label='$z_4$')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks(np.arange(-5, 6))
ax.yaxis.set_ticks(np.arange(-5, 6))

# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))

#ax.set_xlim([-5, 5])
#ax.set_ylim([-5, 5])
ax.grid(visible=True)

ax.set_aspect('equal');
ax.set_xlabel('Re', loc='left')
ax.set_ylabel('Im', loc='top')
ax.set_title('1-1')

ax.legend()

# %% [markdown]
# 2) What are the real and imaginary components of each complex number $z_1,...,z_4$?
#
# | |Real(z)|Imag(z)|
# --|-------|-----|
# $z_1$| | |
# $z_2$| | |
# $z_3$| | |
# $z_4$| | |

# %% [markdown]
# | |Real(z)|Imag(z)|
# --|-------|-----|
# $z_1$|2 | 3|
# $z_2$|-2 |3 |
# $z_3$|$\sqrt{2}$| $-\sqrt{2}$|
# $z_4$|-3| -2|

# %%
print(z1.real, z1.imag)
print(z2.real, z2.imag)
print(z3.real, z3.imag)
print(z4.real, z4.imag)
# Out:
# 2.0 3.0
# -2.0 3.0
# 1.4142135623730951 -1.414213562373095
# -3.0 -1.9999999999999998

# %% [markdown]
# 3) What are the amplitude and phase (in radians) of each complex number $z_1,...,z_4$?
#
# | |Amp(z)|Phase(z)|
# --|-------|-----|
# $z_1$|$\sqrt{13}$ | $\arctan(3/2) \approx 0.9828$|
# $z_2$|$\sqrt{13}$| $\arctan(-3/2) + \pi \approx 2.1588$|
# $z_3$| $2$ | $-\pi/4$|
# $z_4$|$\sqrt{13}$ | $\arctan(2/3) + \pi \approx -2.5536$|

# %%
print(np.abs(z1), np.angle(z1), np.pi/3)
print(np.abs(z2), np.angle(z2), 2*np.pi/3)
print(np.abs(z3), np.angle(z3))
print(np.abs(z4), np.angle(z4), 7*np.pi/6)
# Out:
# 3.6055512754639896 0.982793723247329 1.0471975511965976
# 3.6055512754639896 2.158798930342464 2.0943951023931953
# 2.0 -0.7853981633974482
# 3.6055512754639896 -2.5535900500422257 3.665191429188092

# %%
print(np.abs(z1), np.angle(z1, deg=True))
print(np.abs(z2), np.angle(z2, deg=True))
print(np.abs(z3), np.angle(z3, deg=True))
print(np.abs(z4), np.angle(z4, deg=True))
# Out:
# 3.6055512754639896 56.309932474020215
# 3.6055512754639896 123.69006752597979
# 2.0 -44.99999999999999
# 3.6055512754639896 -146.30993247402023

# %%
np.angle(z2) + np.pi/2
# Out:
# 3.7295952571373605

# %%
np.arctan(2/3) - np.pi
# Out:
# -2.5535900500422257

# %%
np.angle(z4)
# Out:
# -2.5535900500422257

# %% [markdown]
# 4) On you complex plane in Figure 1, draw and label the real component, imaginary component, amplitude, and phase of $z_1$.

# %% [markdown]
# ### Solution

# %% [markdown]
# ### 2. (XX Points)
#
# Consider the 1D scalar wave equation,
#
# $$
# \frac{\partial^2 u}{\partial x^2} = \frac{1}{v^2}\frac{\partial^2 u}{\partial t^2}
# $$
#
# Which of the following equations are valid solutions to the wave equation? **Hint**: Consider the general D'Alembert solution to the 1D wave equation and ask yourself, "Do they fall into the general form $F(x - v t) + G(x + vt)$"?
#
# For example, the equation we have worked with in class, $e^{i(x - v t)}$, is of the form $f(x-vt)$ and therefore is a valid solution.
#
#
# 1) $ u(x, t) = x^2 + 2 x v t + v^2t^2$
#
# **yes** u(x, t) = (x + v t)^2, so it is of the form $g(x+vt)$
#
# 2) $ u(x, t) = x^2 - v^2t^2$
#
# **no** u(x, t) = (x + v t)(x-vt), it is not of the form $g(x+vt)$ or $f(x-vt)$
#
# 3) $ u(x, t) = \delta(x - v t)$
#
# **yes** It is of the form $f(x-vt)$
#
# 4) $ u(x, t) = \begin{cases}cos^2(x + vt) & \textrm{if} |x + vt| < \pi/2 \\ 0 &\textrm{otherwise}\end{cases}$
#
# **yes** It is of the form g(x+vt)$
#
# 5) $ u(x, t) = \cos(x^2 + vt)$
#
# **no** it is not of the form $g(x+vt)$ or $f(x-vt)$
#
# 6) $ u(x, t) = e^{x - vt}$
#
# **yes** It is of the form f(x-vt)$
#
# 7) $ u(x, t) = e^{i (x - vt)^2}$
#
# **yes** It is of the form f(x-vt)$
#
# 8) $ u(x, t) = \frac{1}{x} - \frac{1}{vt}$
#
# **no** it is not of the form $g(x+vt)$ or $f(x-vt)$

# %% [markdown]
# ### 3. (XX points)
#
# Consider the following function: $$u_b(x,t) = \sin(\omega t + k x)$$
#
# 1) What must be the relationship between $\omega$, $k$ and $v$ for this function to be a valid solution to the 1D wave equation?
#
# **answer** $v = \frac{\omega}{k}$
#
# 2) Which direction is this wave traveling (i.e. $+x$, $-x$, $+y$, $-y$, $+z$, $-z$)?
#
# **answer** it is traveling in the $-x$ direction.
#
# 3) If the frequency of wave $u_b$ is 10Hz, and it is traveling through a material with a velocity of 1000 m/s, what would be the wavelength of the wave?

# %% [markdown]
# \begin{align}
# \omega &= 2 \pi f \\
# v &= \frac{\omega}{k}\\
# k &= \frac{2\pi f}{v}\\
# k &= \frac{2\pi}{\lambda}\\
# \lambda &= \frac{2\pi}{k} \\
# & = \frac{2\pi}{\frac{2\pi f}{v}}\\
# & = \frac{1}{\frac{f}{v}}\\
# & = \frac{v}{f}\\
# &= 100 m
# \end{align}

# %% [markdown]
# ### 4. (XX Points)
#
# 1) Match up each of Maxwell's Equations to the corresponding images.
#
# * Gauss's Law: $$\nabla \cdot \vec{E} = \rho_e$$
# * "Gauss's Law" for magnetism: $$\nabla \cdot \vec{B} = 0$$
# * Faraday's Law: $$\nabla \times \vec{E} = -\frac{\partial \vec{B}}{\partial t}$$
# * Ampere's Law with Maxwell's correction: $$\nabla \times \vec{B} = \mu_0 \vec{J} + \mu_0 \varepsilon_0 \frac{\partial \vec{E}}{\partial t}$$
#
# ![a](images/EM_For_babies-4.jpeg)
# ![a](images/EM_For_babies-1.jpeg)
# ![a](images/EM_For_babies-3.jpeg)
# ![a](images/EM_For_babies-2.jpeg)
#
# 2) Label the following fields:
#
# * $\vec{E}$ **Electric Field**
# * $\vec{D}$ **Electric Displacement**
# * $\vec{B}$ **Magnetic Flux Density**
# * $\vec{H}$ **Magnetic Field**
#
# 3) What is the relationship between $\vec{E}$ and $\vec{D}$?
# $$\vec{D} = \epsilon\vec{E}$$
#
# 4) What is the relationship between $\vec{H}$ and $\vec{B}$?
# $$\vec{H} = \frac{1}{\mu} \vec{B}$$

# %% [markdown]
# ### 5.
# Consider the following two layer medium:
#
# \begin{align}
# \mu_1 = \mu_0\\
# \varepsilon_1 = 3 \varepsilon_0\\
# \mu_2 = \mu_0\\
# \varepsilon_2 = 2 \varepsilon_0
# \end{align}
#
# 1. What is the velocity of the electromagnetic wave in each medium, in terms to the speed of light $c$?
#
# \begin{align}
# v_1 &= \frac{1}{\sqrt{\mu_1 \varepsilon_1}}\\
# &= \frac{1}{\sqrt{3 \mu_0 \varepsilon_0}}\\
# &= \frac{1}{\sqrt{3}} c\\
# v_2 &= \frac{1}{\sqrt{2}} c
# \end{align}
#
# 2. What are the reflection and transmission coefficients for a vertically incident magnetic plane wave?
# $$R = \frac{v_1\varepsilon_1 - v_2\varepsilon_2}{v_1\varepsilon_1 + v_2\varepsilon_2}$$
# $$T = \frac{2 v_1\varepsilon_1}{v_1\varepsilon_1 + v_2\varepsilon_2}$$

# %%
R = (3/sp.sqrt(3) - 2/sp.sqrt(2))/(3/sp.sqrt(3) + 2/sp.sqrt(2))
R
# Out:
# (-sqrt(2) + sqrt(3))/(sqrt(2) + sqrt(3))

# %%
(np.sqrt(3) - np.sqrt(2))/(np.sqrt(3) + np.sqrt(2))
# Out:
# 0.10102051443364374

# %%
(5 - 2 * np.sqrt(6))/2
# Out:
# 0.05051025721682212

# %%
(np.sqrt(2) * 3 - np.sqrt(3) * 2)/(np.sqrt(3) * 2 + np.sqrt(2) * 3)
# Out:
# 0.10102051443364389

# %%
T = (2 * 3/sp.sqrt(3))/(3/sp.sqrt(3) + 2/sp.sqrt(2))
T
# Out:
# 2*sqrt(3)/(sqrt(2) + sqrt(3))

# %%
(2 * np.sqrt(3))/(np.sqrt(3) + np.sqrt(2))
# Out:
# 1.1010205144336436

# %%
2 *  np.sqrt(6)/(np.sqrt(6) + 2)
# Out:
# 1.1010205144336438

# %% [markdown]
# 4. If a plane wave approaches the interface at an angle of 45 degrees ($\frac{\pi}{4}$ radians) to the normal, What is the angle of the reflected and transmitted (refracted wave)? **Hint** Consider Snell's law: $$\frac{\sin\theta_I}{\sin\theta_T} = \frac{v_1}{v_2}$$

# %%
mu, eps, c = sp.symbols('\mu_0,\epsilon_0, c')
mu1 = mu
mu2 = mu
e1 = 3 * eps
e2 = 2 * eps

v1 = sp.sqrt(1/(mu1 * e1))
v2 = sp.sqrt(1/(mu2 * e2))
v1.subs(sp.sqrt(1/(mu * eps)), c)
# Out:
# sqrt(3)*c/3

# %%
v2.subs(sp.sqrt(1/(mu * eps)), c)
# Out:
# sqrt(2)*c/2

# %%
sin_theta_T = sp.sin(sp.pi/4) * v2 / v1
sin_theta_T
# Out:
# sqrt(3)/2

# %%
sp.asin(sin_theta_T)
# Out:
# pi/3

# %%
np.pi/3
# Out:
# 1.0471975511965976

# %%
np.pi/3 * 180/np.pi
# Out:
# 59.99999999999999

# %% [markdown]
# 5. The second medium here is faster than the first $v_1 < v_2$, how does $\theta_I$ compare to $\theta_T$?
#
# **answer** $\theta_I$ is smaller than $\theta_T$
#
# 6. If $v_1$ had been greater than $v_2$ (it isn't for this example but hypothetically...), how would $\theta_I$ and $\theta_T$ compare to each other.
#
# **answer** $\theta_I$ would be larger than $\theta_T$

# %% [markdown]
# ### 6.
# Consider the following $\vec{B}$-field in a conductive medium, generated from a circular loop centered at the orgin, normal to the $x$-axis, in the quasi-static regime.
#
# $$\vec{B}(\vec{r}) = \frac{\mu}{4 \pi} \sin(\omega t - k r) \frac{3 (\vec{r} \cdot \hat{x}) \hat{r} - \hat{x}}{r^3} $$
#
# with $$k = \sqrt{\frac{\mu \sigma \omega}{2}}$$
#
# For the following questions assume:
# \begin{align}
# \sigma = 1E-3 \frac{S}{m}\\
# \mu = \mu_0\\
# f = 100 Hz
# \end{align}

# %% [markdown]
# 1) What is the skin depth of the medium?

# %%
# d = 1/k
f = 100
k = np.sqrt(mu_0 * 1E-3 * np.pi * f)
d = 1/k
d
# Out:
# 1591.5494304857532

# %%
np.sqrt(1 / (mu_0 * .1 * np.pi))
# Out:
# 1591.549430485753

# %% [markdown]
# 2) What is the negative time derivative of this function $-\partial \vec{B}/ \partial t$?
#
# **answer**
#
# \begin{align}
# \vec{B} &= \frac{\mu}{4 \pi} \sin(\omega t - k r) \frac{3 (\vec{r} \cdot \hat{x}) \hat{r} - \hat{x}}{r^3}\\
# \frac{\partial}{\partial t} \vec{B} &= \frac{\mu}{4 \pi} (\omega \cos(\omega t - k r)) \frac{3 (\vec{r} \cdot \hat{x}) \hat{r} - \hat{x}}{r^3}\\
# -\frac{\partial}{\partial t} \vec{B} &= -\frac{\mu}{4 \pi} (\omega \cos(\omega t - k r)) \frac{3 (\vec{r} \cdot \hat{x}) \hat{r} - \hat{x}}{r^3}
# \end{align}

# %% [markdown]
# 3) There is second coil of wire centered at $\vec{r}=h\hat{x}$, oriented normal to $\hat{x}$ plane (which would make it parallel to the first loop). At time $t=0$, and a separation of $h=10m$.
#
# Which direction is $-\partial\vec{B}/\partial t$ at the center of the receiver (Rx) coil?
# ![a](images/two-loops.png)

# %% [markdown]
# We can logic this out a bit first:
#
# Seperate the "wave" part and the "amplitude" parts and see what there signs are at the location of interest.
# \begin{align}
# -\frac{\partial}{\partial t} \vec{B} &= -\frac{\mu}{4 \pi}\omega \frac{3 (\vec{r} \cdot \hat{x}) \hat{r} - \hat{x}}{r^3} \cos(\omega t - k r)
# \end{align}
#
# We have that $\vec{r} = h\hat{x}$
#
# \begin{align}
# -\frac{\partial}{\partial t} \vec{B} &= -\frac{\mu}{4 \pi}\omega \frac{3 (h\hat{x} \cdot \hat{x}) \hat{x} - \hat{x}}{h^3} \cos(\omega t - k h)\\
# &= -\frac{\mu}{4 \pi}\omega \frac{(3 h - 1)\hat{x}}{h^3} \cos(\omega t - k h)\\
# &= -\frac{\mu}{4 \pi}\omega \frac{(3 h - 1)}{h^3} \cos(\omega t - k h)\hat{x}
# \end{align}
#
# at $h=10$
# the amplitude part will be positive:
# \begin{align}
# \frac{\mu}{4 \pi}\omega \frac{(30 - 1)}{10^3} > 0
# \end{align}
#
# So what about $\cos(\omega t - k h)$ at t=0?
#
# \begin{align}
# &\cos(2 \pi f 0 - k h)\\
# &=\cos(-k h)\\
# &=\cos(k h) &\textrm{(cos is an odd function)}\\
# &=\cos(\sqrt{\frac{\mu_0 \sigma 2 \pi f}{2}} 10)\\
# &=\cos(10 \sqrt{\mu_0 \sigma \pi 100} )\\
# &\approx\cos(0) & \mu_0\textrm{ is very small } (4\pi 10^{-7})\\
# &=1 > 0
# \end{align}
#
# so the $\cos$ term will be positive there:
#
# so we have
# \begin{align}
# -\frac{\partial \vec{B}}{\partial t} = - (+)(+)\hat{x}
# \end{align}
#
# thus $-\frac{\partial \vec{B}}{\partial t}$ is in the $-\hat{x}$ direction at $t=0$, $h=10m$

# %% [markdown]
# 5) Which direction about the $\hat{x}$ axis will the induced currents run, CW or CCW? (For example, put your right thumb in the direction of $\hat{x}$, If the induced currents go in the direction of your fingers, they would run CCW about $\hat{x}$)
#
# **answer**
# since $-\frac{\partial \vec{B}}{\partial t}$ is in the $-\hat{x}$ direction. We put our right thumb in the $-\hat{x}$ direction and our fingers curl clockwise about the $x$-axis, Thus the currents would go CW about the X-axis.

# %% [markdown]
# Think about it...
# At time t=0 the magnetic flux density is increasing, and the induced currents will want to generate a magnetic field that opposes the increase.

# %%
v1
# Out:
# sqrt(3)*sqrt(1/(\epsilon_0*\mu_0))/3

# %%
v2
# Out:
# sqrt(2)*sqrt(1/(\epsilon_0*\mu_0))/2

# %%
# sin theta_I / sin theta_T = v1/v2
# sin theta_T = v2 / v1 * sin theta_I

theta_I = sp.pi/4
sp.asin(sp.sin(theta_I) * v2 / v1)
# Out:
# pi/3
